# %%
# %load_ext dotenv
# %dotenv

from mise.ai import extract_from_youtube
#recipe, source_metadata, processing_metadata = extract_from_image("/Users/jeff/Downloads/IMG_0699.jpeg")
video = "https://www.youtube.com/watch?v=k_U7Yj08kVs"
recipe, source_metadata, processing_metadata = extract_from_youtube(video)
